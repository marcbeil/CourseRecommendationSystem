# %%
from evaluation.validate_prereq_extraction import plot_metrics_over_thresholds

plot_metrics_over_thresholds(range(0, 101, 5))

# %%
thresholds = range(0, 101, )
plot_metrics_over_thresholds(thresholds, group_by='school')

# %%
from evaluation.validate_prereq_extraction import save_metrics_to_csv
thresholds = range(0, 101, 5)
save_metrics_to_csv(thresholds=thresholds, output_dir="prerequisite_metrics")
# Out:
# Saved overall metrics to prerequisite_metrics/metrics_overall.csv

# %%
plot_metrics_over_thresholds(thresholds=thresholds, group_by="school")

# %%
from evaluation.validate_prereq_extraction import metrics_for_score_threshold

metrics_for_score_threshold(score_threshold=55)
# Out:
# {'ID': {'Precision': 0.9711934156378601,
#   'Recall': 0.7283950617283951,
#   'Accuracy': 0.7129909365558912},
#  'TITLE': {'Precision': 0.6427038626609443,
#   'Recall': 0.8228021978021978,
#   'Accuracy': 0.5645617342130066},
#  'COMBINED': {'Precision': 0.8069486391494022,
#   'Recall': 0.7755986297652964,
#   'Accuracy': 0.6387763353844489}}
